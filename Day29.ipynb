# %% [markdown]
# ## Contents
#
# - Cubehelix palette observations using heat map
# - Different styles of plots in seaborn
#     - Categorical scatter plots
#         - strip plots
#         - swarm plots
#     - Categorical distributed plots
#         - histogram
#         - box plot
#         - kde
#         - violin plot
#     - Categorical Estimator plots
#         - bar plot
#         - point plot
#         - Count plot
# - joint plot
# - pair plot

# %%
import seaborn as sns
import numpy as np
x = np.random.randint(1,20,10).reshape(2,5)
c = sns.cubehelix_palette(as_cmap = True)
sns.heatmap(x,cmap = c)
# Out:
# <AxesSubplot:>

# %%
import seaborn as sns
import numpy as np
x = np.random.randint(1,20,10).reshape(2,5)
c = sns.cubehelix_palette(as_cmap = True)
sns.heatmap(x,cmap = c)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(x)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(x,annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Categorical scatter plots
#         - strip plots
#         - swarm plots

# %% [markdown]
# ## Get dataset from seaborn

# %%
import seaborn as sns
sns.get_dataset_names()##displays the datasets in seaborn
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'tips',
#  'titanic']

# %% [markdown]
# ## Load the dataset

# %%
## Load the dataset

df = sns.load_dataset("iris")
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df.shape
# Out:
# (150, 5)

# %%
df["species"]
# Out:
# 0         setosa
# 1         setosa
# 2         setosa
# 3         setosa
# 4         setosa
#          ...
# 145    virginica
# 146    virginica
# 147    virginica
# 148    virginica
# 149    virginica
# Name: species, Length: 150, dtype: object

# %%
df["species"].value_counts()
# Out:
# setosa        50
# versicolor    50
# virginica     50
# Name: species, dtype: int64

# %%
df["species"].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
df.groupby(by="species").sum()
# Out:
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa             250.3        171.4          73.1         12.3
# versicolor         296.8        138.5         213.0         66.3
# virginica          329.4        148.7         277.6        101.3

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.catplot(data = df)

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
sns.catplot(x= "sepal_length",y= "petal_length",data= df)

# %%
sns.catplot(x= "sepal_length",y= "petal_length",data= df, hue = "species")

# %%
sns.catplot(x= "sepal_length",y= "petal_length",data= df, hue = "petal_width")

# %%
sns.catplot(x= "sepal_length",y= "petal_length",data= df, hue = "species", kind = "box")

# %%
sns.catplot(x= "sepal_length",y= "sepal_width",data= df, hue = "species", kind = "box")

# %%
sns.catplot(x= "sepal_length",y= "species",data= df, hue = "species", kind = "box")

# %%
sns.catplot(x= "sepal_length",y= "species",data= df, hue = "species", kind = "bar",palette =["r","g","b"])

# %%
sns.catplot(x= "sepal_length",y= "species",data= df, hue = "species", kind = "bar")

# %%
sns.catplot(x= "sepal_length",y= "species",data= df, hue = "species", kind = "bar",palette =["r","g","b"], col = "species")

# %%
sns.catplot(x= "sepal_length",y= "species",data= df, hue = "species", kind = "violin",palette =["r","g","b"], col = "species")

# %%
sns.catplot(x= "sepal_length",y= "species",data= df,palette =["r","g","b"], col = "species", marker= "*")

# %%
sns.catplot(x= "sepal_length",y= "species",data= df,palette =["r","g","b"], col = "species", marker= "^")

# %%
sns.catplot(x= "sepal_length",y= "species",data= df,kind = "boxen",palette =["r","g","b"])

# %% [markdown]
# ## Categorical distributed plots
# - histogram
# - box plot
# - kde
# - violin plot

# %% [markdown]
# ## Histogram plots

# %%
df = sns.load_dataset("tips")
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
sns.histplot(data = df)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
sns.histplot(x = "total_bill",data = df)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Count'>

# %%
sns.histplot(x = "sex",data = df)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='Count'>

# %%
sns.histplot(x = "tip",data = df)
# Out:
# <AxesSubplot:xlabel='tip', ylabel='Count'>

# %%
sns.histplot(x = "total_bill",data = df, bins = 5)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Count'>

# %%
sns.histplot(y = "total_bill",data = df, bins = 5)
# Out:
# <AxesSubplot:xlabel='Count', ylabel='total_bill'>

# %%
sns.histplot(y = "total_bill",data = df, bins = 5,binwidth  = 0.5)
# Out:
# <AxesSubplot:xlabel='Count', ylabel='total_bill'>

# %%
sns.histplot(y = "total_bill",data = df, bins = 5,binwidth  = 10)
# Out:
# <AxesSubplot:xlabel='Count', ylabel='total_bill'>

# %%
sns.histplot(x = "total_bill",data = df, bins = 5,binwidth  = 1)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Count'>

# %%
sns.histplot(x = "total_bill",data = df, bins = 5,kde = True)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Count'>

# %%
sns.histplot(y = "total_bill",data = df, bins = 5,kde = True)
# Out:
# <AxesSubplot:xlabel='Count', ylabel='total_bill'>

# %%
sns.histplot(x = "total_bill",data = df,hue = "sex")
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Count'>

# %%
sns.histplot(x = "total_bill",data = df,hue = "sex",color = ["r","g"])
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Count'>
